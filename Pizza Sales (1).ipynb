# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
pizza_order_details = pd.read_csv("/home/annabella/Documents/Pizza-Place-Sales/pizza_sales/order_details.csv")

# %%
pizza_orders = pd.read_csv("/home/annabella/Documents/Pizza-Place-Sales/pizza_sales/orders.csv")

# %%
pizzas = pd.read_csv("/home/annabella/Documents/Pizza-Place-Sales/pizza_sales/pizzas.csv")

# %%
pizza_types = pd.read_csv("/home/annabella/Documents/Pizza-Place-Sales/pizza_sales/pizza_types.csv")

# %%
data_dictionary = pd.read_csv("/home/annabella/Documents/Pizza-Place-Sales/data_dictionary.csv")

# %%
data_dictionary
# Out:
#             Table             Field  \
# 0          orders          order_id
# 1          orders              date
# 2          orders              time
# 3   order_details  order_details_id
# 4   order_details          order_id
# 5   order_details          pizza_id
# 6   order_details          quantity
# 7          pizzas          pizza_id
# 8          pizzas     pizza_type_id
# 9          pizzas              size
# 10         pizzas             price
# 11    pizza_types     pizza_type_id
# 12    pizza_types              name
# 13    pizza_types          category
# 14    pizza_types       ingredients
#
#                                           Description
# 0   Unique identifier for each order placed by a t...
# 1   Date the order was placed (entered into the sy...
# 2   Time the order was placed (entered into the sy...
# 3   Unique identifier for each pizza placed within...
# 4   Foreign key that ties the details in each orde...
# ...

# %%
pizza_order_details
# Out:
#        order_details_id  order_id       pizza_id  quantity
# 0                     1         1     hawaiian_m         1
# 1                     2         2  classic_dlx_m         1
# 2                     3         2  five_cheese_l         1
# 3                     4         2    ital_supr_l         1
# 4                     5         2     mexicana_m         1
# ...                 ...       ...            ...       ...
# 48615             48616     21348  ckn_alfredo_m         1
# 48616             48617     21348  four_cheese_l         1
# 48617             48618     21348   napolitana_s         1
# 48618             48619     21349     mexicana_l         1
# 48619             48620     21350      bbq_ckn_s         1
#
# [48620 rows x 4 columns]

# %%
pizza_orders
# Out:
#        order_id        date      time
# 0             1  2015-01-01  11:38:36
# 1             2  2015-01-01  11:57:40
# 2             3  2015-01-01  12:12:28
# 3             4  2015-01-01  12:16:31
# 4             5  2015-01-01  12:21:30
# ...         ...         ...       ...
# 21345     21346  2015-12-31  20:51:07
# 21346     21347  2015-12-31  21:14:37
# 21347     21348  2015-12-31  21:23:10
# 21348     21349  2015-12-31  22:09:54
# 21349     21350  2015-12-31  23:02:05
#
# [21350 rows x 3 columns]

# %%
pizza1 = pd.merge(pizza_order_details,pizza_orders, on="order_id", how="inner")

# %%
pizza1
# Out:
#        order_details_id  order_id       pizza_id  quantity        date  \
# 0                     1         1     hawaiian_m         1  2015-01-01
# 1                     2         2  classic_dlx_m         1  2015-01-01
# 2                     3         2  five_cheese_l         1  2015-01-01
# 3                     4         2    ital_supr_l         1  2015-01-01
# 4                     5         2     mexicana_m         1  2015-01-01
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  2015-12-31
# 48616             48617     21348  four_cheese_l         1  2015-12-31
# 48617             48618     21348   napolitana_s         1  2015-12-31
# 48618             48619     21349     mexicana_l         1  2015-12-31
# 48619             48620     21350      bbq_ckn_s         1  2015-12-31
#
#            time
# 0      11:38:36
# 1      11:57:40
# 2      11:57:40
# 3      11:57:40
# 4      11:57:40
# ...

# %%
pizzas
# Out:
#          pizza_id pizza_type_id size  price
# 0       bbq_ckn_s       bbq_ckn    S  12.75
# 1       bbq_ckn_m       bbq_ckn    M  16.75
# 2       bbq_ckn_l       bbq_ckn    L  20.75
# 3      cali_ckn_s      cali_ckn    S  12.75
# 4      cali_ckn_m      cali_ckn    M  16.75
# ..            ...           ...  ...    ...
# 91  spinach_fet_m   spinach_fet    M  16.00
# 92  spinach_fet_l   spinach_fet    L  20.25
# 93   veggie_veg_s    veggie_veg    S  12.00
# 94   veggie_veg_m    veggie_veg    M  16.00
# 95   veggie_veg_l    veggie_veg    L  20.25
#
# [96 rows x 4 columns]

# %%
pizza2 = pd.merge(pizza1, pizzas, on="pizza_id", how="inner")

# %%
pizza2
# Out:
#        order_details_id  order_id       pizza_id  quantity        date  \
# 0                     1         1     hawaiian_m         1  2015-01-01
# 1                   179        77     hawaiian_m         1  2015-01-02
# 2                   357       146     hawaiian_m         1  2015-01-03
# 3                   389       163     hawaiian_m         1  2015-01-03
# 4                   568       247     hawaiian_m         1  2015-01-04
# ...                 ...       ...            ...       ...         ...
# 48615             39733     17492  the_greek_xxl         1  2015-10-24
# 48616             41183     18139  the_greek_xxl         1  2015-11-05
# 48617             42718     18789  the_greek_xxl         1  2015-11-17
# 48618             43041     18919  the_greek_xxl         1  2015-11-19
# 48619             47490     20866  the_greek_xxl         1  2015-12-20
#
#            time pizza_type_id size  price
# 0      11:38:36      hawaiian    M  13.25
# ...

# %%
pizza_types
# Out:
#    pizza_type_id                                        name category  \
# 0        bbq_ckn                  The Barbecue Chicken Pizza  Chicken
# 1       cali_ckn                The California Chicken Pizza  Chicken
# 2    ckn_alfredo                   The Chicken Alfredo Pizza  Chicken
# 3      ckn_pesto                     The Chicken Pesto Pizza  Chicken
# 4     southw_ckn                 The Southwest Chicken Pizza  Chicken
# 5       thai_ckn                      The Thai Chicken Pizza  Chicken
# 6       big_meat                          The Big Meat Pizza  Classic
# 7    classic_dlx                    The Classic Deluxe Pizza  Classic
# 8       hawaiian                          The Hawaiian Pizza  Classic
# 9    ital_cpcllo                 The Italian Capocollo Pizza  Classic
# 10    napolitana                        The Napolitana Pizza  Classic
# 11   pep_msh_pep  The Pepperoni, Mushroom, and Peppers Pizza  Classic
# ...

# %%
df = pd.merge(pizza2, pizza_types, on="pizza_type_id", how="inner")

# %%
df
# Out:
#        order_details_id  order_id      pizza_id  quantity        date  \
# 0                     1         1    hawaiian_m         1  2015-01-01
# 1                   179        77    hawaiian_m         1  2015-01-02
# 2                   357       146    hawaiian_m         1  2015-01-03
# 3                   389       163    hawaiian_m         1  2015-01-03
# 4                   568       247    hawaiian_m         1  2015-01-04
# ...                 ...       ...           ...       ...         ...
# 48615             48176     21167  brie_carre_s         1  2015-12-27
# 48616             48244     21198  brie_carre_s         1  2015-12-28
# 48617             48311     21225  brie_carre_s         1  2015-12-29
# 48618             48456     21282  brie_carre_s         1  2015-12-31
# 48619             48527     21308  brie_carre_s         1  2015-12-31
#
#            time pizza_type_id size  price                  name category  \
# ...

# %%
df_backup = df.copy()

# %%
df.head()
# Out:
#    order_details_id  order_id    pizza_id  quantity        date      time  \
# 0                 1         1  hawaiian_m         1  2015-01-01  11:38:36
# 1               179        77  hawaiian_m         1  2015-01-02  12:22:46
# 2               357       146  hawaiian_m         1  2015-01-03  14:22:10
# 3               389       163  hawaiian_m         1  2015-01-03  16:54:54
# 4               568       247  hawaiian_m         1  2015-01-04  20:55:29
#
#   pizza_type_id size  price                name category  \
# 0      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 1      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 2      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 3      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 4      hawaiian    M  13.25  The Hawaiian Pizza  Classic
#
#                                 ingredients
# 0  Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Sliced Ham, Pineapple, Mozzarella Cheese
# ...

# %%
df.sample(10)
# Out:
#        order_details_id  order_id        pizza_id  quantity        date  \
# 42615             13798      6044   spinach_fet_l         1  2015-04-12
# 4639              34064     15045   classic_dlx_l         1  2015-09-09
# 24807              7385      3255    southw_ckn_l         1  2015-02-24
# 6518              24717     10870     ital_supr_l         1  2015-07-02
# 40457              4980      2201  mediterraneo_l         1  2015-02-06
# 39433             41470     18253   ital_veggie_s         1  2015-11-07
# 15234             29848     13181       bbq_ckn_m         1  2015-08-08
# 11400             10912      4776      thai_ckn_s         1  2015-03-21
# 36166             46315     20343   four_cheese_l         1  2015-12-11
# 16542             22627      9944     the_greek_m         1  2015-06-16
#
#            time pizza_type_id size  price                          name  \
# 42615  12:30:38   spinach_fet    L  20.25    The Spinach and Feta Pizza
# ...

# %%
df.describe()
# Out:
#        order_details_id      order_id      quantity         price
# count      48620.000000  48620.000000  48620.000000  48620.000000
# mean       24310.500000  10701.479761      1.019622     16.494132
# std        14035.529381   6180.119770      0.143077      3.621789
# min            1.000000      1.000000      1.000000      9.750000
# 25%        12155.750000   5337.000000      1.000000     12.750000
# 50%        24310.500000  10682.500000      1.000000     16.500000
# 75%        36465.250000  16100.000000      1.000000     20.250000
# max        48620.000000  21350.000000      4.000000     35.950000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  object
#  5   time              48620 non-null  object
#  6   pizza_type_id     48620 non-null  object
#  7   size              48620 non-null  object
#  8   price             48620 non-null  float64
#  9   name              48620 non-null  object
#  10  category          48620 non-null  object
#  11  ingredients       48620 non-null  object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 4.5+ MB

# %%
df.isna().sum()
# Out:
# order_details_id    0
# order_id            0
# pizza_id            0
# quantity            0
# date                0
# time                0
# pizza_type_id       0
# size                0
# price               0
# name                0
# category            0
# ingredients         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["order_details_id"]
# Out:
# 0            1
# 1          179
# 2          357
# 3          389
# 4          568
#          ...
# 48615    48176
# 48616    48244
# 48617    48311
# 48618    48456
# 48619    48527
# Name: order_details_id, Length: 48620, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  object
#  5   time              48620 non-null  object
#  6   pizza_type_id     48620 non-null  object
#  7   size              48620 non-null  object
#  8   price             48620 non-null  float64
#  9   name              48620 non-null  object
#  10  category          48620 non-null  object
#  11  ingredients       48620 non-null  object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 4.5+ MB

# %%
df["order_details_id"]= df["order_details_id"].astype(object) # convert order details to object dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  object
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  object
#  5   time              48620 non-null  object
#  6   pizza_type_id     48620 non-null  object
#  7   size              48620 non-null  object
#  8   price             48620 non-null  float64
#  9   name              48620 non-null  object
#  10  category          48620 non-null  object
#  11  ingredients       48620 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 4.5+ MB

# %%
df["order_id"] = df["order_id"].astype(object) #convert order id to object dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  object
#  1   order_id          48620 non-null  object
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  object
#  5   time              48620 non-null  object
#  6   pizza_type_id     48620 non-null  object
#  7   size              48620 non-null  object
#  8   price             48620 non-null  float64
#  9   name              48620 non-null  object
#  10  category          48620 non-null  object
#  11  ingredients       48620 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 4.5+ MB

# %%
df["date"]= pd.to_datetime(df["date"]) # convert date to datetime dtype

# %%
df.head()
# Out:
#   order_details_id order_id    pizza_id  quantity       date      time  \
# 0                1        1  hawaiian_m         1 2015-01-01  11:38:36
# 1              179       77  hawaiian_m         1 2015-01-02  12:22:46
# 2              357      146  hawaiian_m         1 2015-01-03  14:22:10
# 3              389      163  hawaiian_m         1 2015-01-03  16:54:54
# 4              568      247  hawaiian_m         1 2015-01-04  20:55:29
#
#   pizza_type_id size  price                name category  \
# 0      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 1      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 2      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 3      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 4      hawaiian    M  13.25  The Hawaiian Pizza  Classic
#
#                                 ingredients
# 0  Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Sliced Ham, Pineapple, Mozzarella Cheese
# 2  Sliced Ham, Pineapple, Mozzarella Cheese
# ...

# %%
df["time"]
# Out:
# 0        11:38:36
# 1        12:22:46
# 2        14:22:10
# 3        16:54:54
# 4        20:55:29
#            ...
# 48615    17:39:57
# 48616    15:39:02
# 48617    13:20:17
# 48618    12:09:59
# 48619    16:44:35
# Name: time, Length: 48620, dtype: object

# %%
df["time"] = pd.to_datetime(df["time"], format="%H:%M:%S") #convert time to datetime dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  object
#  1   order_id          48620 non-null  object
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  datetime64[ns]
#  5   time              48620 non-null  datetime64[ns]
#  6   pizza_type_id     48620 non-null  object
#  7   size              48620 non-null  object
#  8   price             48620 non-null  float64
#  9   name              48620 non-null  object
#  10  category          48620 non-null  object
#  11  ingredients       48620 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(8)
# memory usage: 4.5+ MB

# %%
df["quantity"].sum()# number of pizzas sold
# Out:
# 49574

# %%
df["Total Cost"] = df["quantity"]*df["price"] # total pizza sold per order

# %%
df["Total Cost"].sum() # total revenue
# Out:
# 817860.05

# %%
df["price"].mean() # average cost of pizza
# Out:
# 16.494132044426163

# %%
df["price"].std() # standard deviation of pizza price
# Out:
# 3.6217891586575446

# %% [markdown]
# ## The total number of sales made is 49574
# ## Total revenue made is $81780.05
# ## The number orders placed is 48620
# ## The average cost of pizza is 16 with a standard deviation of aproximately 4
# ## Thus, if a customer has between 12-20 dollars
# ## You can get something to buy

# %%
df["order_details_id"].value_counts().sum() #number of orders placed
# Out:
# 48620

# %%
pizza_types= df.groupby("name")["Total Cost"].sum().reset_index() # group pizza types by total cost

# %%
pizza_types
# Out:
#                                           name  Total Cost
# 0                   The Barbecue Chicken Pizza    42768.00
# 1                           The Big Meat Pizza    22968.00
# 2                         The Brie Carre Pizza    11588.50
# 3                          The Calabrese Pizza    15934.25
# 4                 The California Chicken Pizza    41409.50
# 5                    The Chicken Alfredo Pizza    16900.25
# 6                      The Chicken Pesto Pizza    16701.75
# 7                     The Classic Deluxe Pizza    38180.50
# 8                        The Five Cheese Pizza    26066.50
# 9                        The Four Cheese Pizza    32265.70
# 10                             The Greek Pizza    28454.10
# 11                      The Green Garden Pizza    13955.75
# 12                          The Hawaiian Pizza    32273.25
# 13                 The Italian Capocollo Pizza    25094.00
# 14                   The Italian Supreme Pizza    33476.75
# ...

# %%
pizza_types.sort_values(by="Total Cost", ascending=False,inplace=True) # to determine highest selling pizza

# %%
pizza_types
# Out:
#                                           name  Total Cost
# 30                      The Thai Chicken Pizza    43434.25
# 0                   The Barbecue Chicken Pizza    42768.00
# 4                 The California Chicken Pizza    41409.50
# 7                     The Classic Deluxe Pizza    38180.50
# 26                     The Spicy Italian Pizza    34831.25
# 25                 The Southwest Chicken Pizza    34705.75
# 14                   The Italian Supreme Pizza    33476.75
# 12                          The Hawaiian Pizza    32273.25
# 9                        The Four Cheese Pizza    32265.70
# 23                          The Sicilian Pizza    30940.50
# 20                         The Pepperoni Pizza    30161.75
# 10                             The Greek Pizza    28454.10
# 17                          The Mexicana Pizza    26780.75
# 8                        The Five Cheese Pizza    26066.50
# 19                     The Pepper Salami Pizza    25529.00
# ...

# %%
plt.bar(pizza_types["name"],pizza_types["Total Cost"])
plt.xticks(rotation=90)
plt.title("Income per pizza")
plt.xlabel("Pizza type")
plt.ylabel("Revenue ($)")
plt.show()

# %% [markdown]
# ## 32 pizza types, The Thai Chicken Pizza raked in the highest revenue.

# %%
pizza_types_count =df["name"].value_counts()

# %%
pizza_types_count.values
# Out:
# array([2416, 2372, 2370, 2369, 2315, 2302, 1887, 1887, 1885, 1850, 1849,
#        1811, 1510, 1456, 1451, 1432, 1428, 1422, 1414, 1406, 1359, 1342,
#         987,  980,  975,  961,  957,  957,  940,  927,  923,  480])

# %%
plt.bar(pizza_types_count.index,pizza_types_count.values)
plt.xticks(rotation=90)
plt.title("Most Sold Pizza")
plt.xlabel("Pizza types")
plt.ylabel("Number of sales")
plt.show()

# %% [markdown]
# # Thoughts
# The classic deluxe pizza had high sales, but in terms of revenue, was the fourth highest source of revenue.
# The Thai chicken pizza had the fifth highest sales but in terms of revenue, was the highest source of revenue
# The cost of a classic deluxe pizza is 12 and that of the thai chicken is $20.75.
# Classic deluxe maybe a favourite and preferred because of affordability.
# # The top five selling pizzas are;
# #### 1.The classic pizza
# #### 2.The barbecue chicken pizza
# #### 3.The Hawaiian pizza
# #### 4.The pepperoni pizza
# #### 5.The thai chicken pizza.
# However, in terms of revenue;
# # the top five income rakers are
# #### 1.Thai Chicken Pizza
# #### 2.The Barbecue Chicken Pizza
# #### 3.The California Chicken Pizza
# #### 4.The Classic Deluxe Pizza
# #### 5.The Spicy Italian Pizza
# # The Brie Carre pizza performs very badly in terms of sales and revenue.

# %%
pizza_category = df.groupby("category")["Total Cost"].sum().reset_index() #categories by total cost

# %%
pizza_category
# Out:
#   category  Total Cost
# 0  Chicken   195919.50
# 1  Classic   220053.10
# 2  Supreme   208197.00
# 3   Veggie   193690.45

# %%
pizza_category.sort_values(by="Total Cost", inplace=True, ascending=False) #determine highest selling category

# %%
pizza_category
# Out:
#   category  Total Cost
# 1  Classic   220053.10
# 2  Supreme   208197.00
# 0  Chicken   195919.50
# 3   Veggie   193690.45

# %%
pizza_category_count= df["category"].value_counts()

# %%
pizza_category_count
# Out:
# category
# Classic    14579
# Supreme    11777
# Veggie     11449
# Chicken    10815
# Name: count, dtype: int64

# %%
plt.pie(pizza_category_count,labels=pizza_category_count.index, autopct="%1.1f%%",colors=["navy","lightblue","skyblue","blue"])
plt.title("Sales per category")
plt.show()

# %%
df.groupby("category")["price"].mean().reset_index().sort_values(by="price",ascending=False) # sorting categories by price
# Out:
#   category      price
# 0  Chicken  17.709408
# 2  Supreme  17.363229
# 3   Veggie  16.612639
# 1  Classic  14.797490

# %% [markdown]
# ## There are four pizza categories with classic pizzas recording highest sales and revenue. On average, a lot more people order classic pizzas.
# ## Averagely, the cost of classic pizzas is the cheapest and the chicken category has the highest average price.
# ## Thus, a lot more people, go for the affordable option

# %%
#correlation

# %%
pizza_type_category = df.groupby(["name","category"])["Total Cost"].agg([np.sum,np.mean]).reset_index()

# %%
pizza_type_category
# Out:
#                                           name category       sum       mean
# 0                   The Barbecue Chicken Pizza  Chicken  42768.00  18.030354
# 1                           The Big Meat Pizza  Classic  22968.00  12.682496
# 2                         The Brie Carre Pizza  Supreme  11588.50  24.142708
# 3                          The Calabrese Pizza  Supreme  15934.25  17.189051
# 4                 The California Chicken Pizza  Chicken  41409.50  17.988488
# 5                    The Chicken Alfredo Pizza  Chicken  16900.25  17.245153
# 6                      The Chicken Pesto Pizza  Chicken  16701.75  17.379553
# 7                     The Classic Deluxe Pizza  Classic  38180.50  15.803187
# 8                        The Five Cheese Pizza   Veggie  26066.50  19.180648
# 9                        The Four Cheese Pizza   Veggie  32265.70  17.440919
# 10                             The Greek Pizza  Classic  28454.10  20.237624
# ...

# %%
df["Month"]= df["date"].dt.month_name()

# %%
df["Day"]= df["date"].dt.day_name()

# %%
df.head()
# Out:
#   order_details_id order_id    pizza_id  quantity       date  \
# 0                1        1  hawaiian_m         1 2015-01-01
# 1              179       77  hawaiian_m         1 2015-01-02
# 2              357      146  hawaiian_m         1 2015-01-03
# 3              389      163  hawaiian_m         1 2015-01-03
# 4              568      247  hawaiian_m         1 2015-01-04
#
#                  time pizza_type_id size  price                name category  \
# 0 1900-01-01 11:38:36      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 1 1900-01-01 12:22:46      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 2 1900-01-01 14:22:10      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 3 1900-01-01 16:54:54      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 4 1900-01-01 20:55:29      hawaiian    M  13.25  The Hawaiian Pizza  Classic
#
#                                 ingredients  Total Cost    Month       Day
# ...

# %%
df["Hour"] = df["time"].dt.hour

# %%
sales_per_hour= df.groupby("Hour")["quantity"].sum().reset_index().sort_values(by="Hour",ascending=False)

# %%
sales_per_hour
# Out:
#     Hour  quantity
# 14    23        68
# 13    22      1386
# 12    21      2545
# 11    20      3534
# 10    19      4406
# 9     18      5417
# 8     17      5211
# 7     16      4239
# 6     15      3216
# 5     14      3613
# 4     13      6413
# 3     12      6776
# 2     11      2728
# 1     10        18
# 0      9         4

# %%
plt.plot(sales_per_hour["Hour"],sales_per_hour["quantity"])
plt.title("Total sales made per hour")
plt.xlabel("Hour")
plt.ylabel("Quantity of pizza sold")
plt.show()

# %% [markdown]
# ## Peak sales are made between 12pm to 1pm.
# ## 12pm to 1pm could be a lunch break period
# ## Hence the pizza place has to ensure pizzas are readily available during such periods to maximise profits

# %%
df.head()
# Out:
#   order_details_id order_id    pizza_id  quantity       date  \
# 0                1        1  hawaiian_m         1 2015-01-01
# 1              179       77  hawaiian_m         1 2015-01-02
# 2              357      146  hawaiian_m         1 2015-01-03
# 3              389      163  hawaiian_m         1 2015-01-03
# 4              568      247  hawaiian_m         1 2015-01-04
#
#                  time pizza_type_id size  price                name category  \
# 0 1900-01-01 11:38:36      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 1 1900-01-01 12:22:46      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 2 1900-01-01 14:22:10      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 3 1900-01-01 16:54:54      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 4 1900-01-01 20:55:29      hawaiian    M  13.25  The Hawaiian Pizza  Classic
#
#                                 ingredients  Total Cost    Month       Day  \
# ...

# %%
quantity_per_day=df.groupby(["Day"])["quantity"].sum().reset_index().sort_values(by="quantity",ascending=False) 
quantity_per_day
# Out:
#          Day  quantity
# 0     Friday      8242
# 2   Saturday      7493
# 4   Thursday      7478
# 6  Wednesday      6946
# 5    Tuesday      6895
# 1     Monday      6485
# 3     Sunday      6035

# %%
plt.bar(quantity_per_day["Day"],quantity_per_day["quantity"])
plt.title("Quantity of pizza sold per day")
plt.xlabel("Day")
plt.ylabel("Quantity of Pizza")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Friday records highest sales followed by saturday.

# %%
quantity_per_month= df.groupby("Month")["quantity"].sum().reset_index().sort_values(by="quantity", ascending=False)
quantity_per_month
# Out:
#         Month  quantity
# 5        July      4392
# 8         May      4328
# 9    November      4266
# 7       March      4261
# 4     January      4232
# 1      August      4168
# 0       April      4151
# 6        June      4107
# 3    February      3961
# 2    December      3935
# 11  September      3890
# 10    October      3883

# %%
plt.bar(quantity_per_month["Month"],quantity_per_month["quantity"])
plt.xticks(rotation=90)
plt.title("Quantity of pizza sold per month")
plt.xlabel("Month")
plt.ylabel("Quantity Sold")
plt.show()

# %% [markdown]
# ## There isn't much difference in the quantity for each month.
# ## However, the sales in September,October,December and February raises some questions.
# ## How and why did sales reduce from January to February and increased in March.
# ## The fluctuations are quite strange.

# %%
df.pivot_table(index="name",columns="Month",values="quantity",aggfunc=np.sum)
# Out:
# Month                                       April  August  December  February  \
# name
# The Barbecue Chicken Pizza                    214     187       176       193
# The Big Meat Pizza                            139     160       157       151
# The Brie Carre Pizza                           32      43        35        44
# The Calabrese Pizza                            83      73        65        86
# The California Chicken Pizza                  176     231       207       204
# The Chicken Alfredo Pizza                      74      83        75        74
# The Chicken Pesto Pizza                        89      81        82        82
# The Classic Deluxe Pizza                      216     208       197       173
# The Five Cheese Pizza                         107     113        89       113
# The Four Cheese Pizza                         162     139       160       160
# The Greek Pizza                               150     112       110       105
# ...

# %% [markdown]
# # Key Business Insights & Strategic Recommendations
# ## 1. Peak Sales Time: 12pm–1pm (Lunch Rush)
#
# ### Insight:
#
# Sales peak during lunchtime (12pm–1pm).
#
# ### Implications:
#
# 1. This is the highest-demand operational window.
#
# 2. Efficiency and speed are critical during this hour.
#
# ### Recommendations:
#
# 1. Increase staff during peak hours.
#
# 2. Pre-prepare high-demand pizzas before noon.
#
# 3. Reduce waiting time to improve customer satisfaction.
#
# 4. Consider slight price optimization if demand is very strong.
#
# ## Classic Category = Highest Sales & Revenue
#
# ### Insight:
#
# 1. The Classic category generates the highest volume and revenue.
#
# 2. It is the core revenue driver.
#
# ### Implications:
#
# 1. This is the backbone of the business.
#
# 2. Strong and stable customer demand.
#
# ### Recommendations:
#
# 1. Feature Classics as “Signature” or “Best Seller.”
#
# 2. Bundle with drinks/sides to increase average order value.
#
# 3. Maintain quality consistency.
#
# ## 3. Chicken Pizza = Highest Average Price & Still Popular
#
# ### Insight:
#
# 1. Chicken pizzas have the highest average price.
#
# 2. They still perform well in demand(The thai chicken pizza,the barbecue chicken pizza, the carlifonia chicken pizza)
#
# ### Implications:
#
# 1. Customers are willing to pay more for it.
#
# ### Recommendations:
#
# 1. Use limited-time promotions (not constant discounts).
#
# 2. Position as a premium “Chef’s Special.”
#
# 3. Use it strategically to drive traffic on slow days.
#
# ## Fridays & Saturdays = Highest Sales
# ### Sundays & Mondays = Lowest Sales
#
# ### Insight:
#
# 1. Weekend demand is strong.
#
# 2. Early-week demand is weak.
#
# ### Recommendations:
# 1. Ensure enough staff presence during fridays and saturdays
# 2. Consider themed promotions(e.g Barbecue Monday) to boost sales for monday and sunday and midweek
